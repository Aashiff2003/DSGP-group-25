# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.5/112.6 GB disk)

# %%
# !pip install -U torch sahi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 12.8 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=b0842d84ea72999b337add79ff020e4f52edb0a3e9a25a781e6a2986adeed48c
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# arrange an instance segmentation model for test
from sahi.utils.ultralytics import (
    download_yolov8n_model
    # download_yolov8n_model, download_yolov8n_seg_model
)

from sahi import AutoDetectionModel
from sahi.utils.cv import read_image
from sahi.utils.file import download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DSGP/Model4
# Out:
# /content/drive/MyDrive/DSGP/Model4

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=100 imgsz=640 plots=True batch=16 lr0=0.001
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **Validate Model**

# %%
# !yolo task=detect mode=val model=runs/detect/train7/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/DSGP/Model4/Data/valid/labels.cache... 150 images, 50 backgrounds, 0 corrupt: 100% 150/150 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:26<00:00,  2.64s/it]
#                    all        150        481      0.232      0.102     0.0965     0.0283
# Speed: 2.4ms preprocess, 153.9ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# **Inference with model**

# %%
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.25 source=Data/test/images
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/200 /content/drive/MyDrive/DSGP/Model4/Data/test/images/007a7f83-0001596.png: 384x640 (no detections), 112.2ms
# image 2/200 /content/drive/MyDrive/DSGP/Model4/Data/test/images/01ca576d-D02_20210628090856_0000225.png: 384x640 (no detections), 108.5ms
# image 3/200 /content/drive/MyDrive/DSGP/Model4/Data/test/images/04f031bd-D02_20210628090856_0000229.png: 384x640 (no detections), 101.7ms
# image 4/200 /content/drive/MyDrive/DSGP/Model4/Data/test/images/07a1d4d0-D01_20210502070930_0033775.png: 384x640 (no detections), 125.3ms
# image 5/200 /content/drive/MyDrive/DSGP/Model4/Data/test/images/081fc519-D02_20210628090856_0000226.png: 384x640 (no detections), 129.9ms
# image 6/200 /content/drive/MyDrive/DSGP/Model4/Data/test/images/085594e0-D02_20210628090856_0000069.png: 384x640 (no detections), 127.4ms
# ...

# %%
# model_type = "ultralytics"
# model_path = "runs/detect/train7/weights/best.pt"
# model_device = "cpu" # or 'cuda:0'
# model_confidence_threshold = 0.4

# slice_height = 256
# slice_width = 256
# overlap_height_ratio = 0.2
# overlap_width_ratio = 0.2

# source_image_dir = "Data/test/images"

# %%
# predict(
#     model_type=model_type,
#     model_path=model_path,
#     model_device=model_device,
#     model_confidence_threshold=model_confidence_threshold,
#     source=source_image_dir,
#     slice_height=slice_height,
#     slice_width=slice_width,
#     overlap_height_ratio=overlap_height_ratio,
#     overlap_width_ratio=overlap_width_ratio,
# )

# %% [markdown]
# Standard

# %%
# detection_model= AutoDetectionModel.from_pretrained(
#     model_type='yolov8',
#     model_path="runs/detect/train7/weights/best.pt",
#     confidence_threshold=0.1,
#     device="cpu"
# )

# %%
# result = get_prediction("/content/drive/MyDrive/DSGP/Model4/demo_data/1b24dd15-D02_20210702082355_0019238.png", detection_model)

# %%
# result.export_visuals(export_dir="/content/drive/MyDrive/DSGP/Model4/demo_data/")

# Image("/content/drive/MyDrive/DSGP/Model4/demo_data/prediction_visual.png")

# %% [markdown]
# With Sahi

# %%
# result = get_sliced_prediction(
#     "/content/drive/MyDrive/DSGP/Model4/demo_data/1b24dd15-D02_20210702082355_0019238.png",
#     detection_model,
#     slice_height = 256,
#     slice_width = 256,
#     overlap_height_ratio = 0.2,
#     overlap_width_ratio = 0.2
# )

# %%
# result.export_visuals(export_dir="/content/drive/MyDrive/DSGP/Model4/demo_data/")

# Image("/content/drive/MyDrive/DSGP/Model4/demo_data/prediction_visual.png")
