# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.84 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.0/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DSGP/Model6
# Out:
# /content/drive/MyDrive/DSGP/Model6

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=data.yaml epochs=50 imgsz=640 plots=True batch=16 lr0=0.001
# Out:
# Ultralytics 8.3.84 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train7/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.84 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/DSGP/Model6/data/valid/labels.cache... 66 images, 0 backgrounds, 0 corrupt: 100% 66/66 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:02<00:00,  1.93it/s]
#                    all         66        543      0.467      0.118      0.165     0.0369
# Speed: 4.6ms preprocess, 13.5ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics 8.3.84 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/13 /content/drive/MyDrive/DSGP/Model6/data/test/images/01bea0ce-D01_20210324125246_0001786.png: 384x640 5 Birds, 45.1ms
# image 2/13 /content/drive/MyDrive/DSGP/Model6/data/test/images/38faa6b3-D01_20210417085147_0060445.png: 384x640 (no detections), 12.0ms
# image 3/13 /content/drive/MyDrive/DSGP/Model6/data/test/images/3b63d942-D01_20210417085147_0053088.png: 384x640 2 Birds, 12.9ms
# image 4/13 /content/drive/MyDrive/DSGP/Model6/data/test/images/55100ed6-D01_20210313085021_0225418.png: 384x640 (no detections), 15.4ms
# image 5/13 /content/drive/MyDrive/DSGP/Model6/data/test/images/601f1029-D01_20210313085021_0227864.png: 384x640 (no detections), 8.7ms
# image 6/13 /content/drive/MyDrive/DSGP/Model6/data/test/images/70590fc7-D01_20210313085021_0211630.png: 384x640 (no detections), 8.9ms
# ...
